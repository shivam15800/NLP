# %%
print("NLP")
# Out:
# NLP

# %% [markdown]
# # Writing to a file

# %%
# open('sample1.txt', 'w')
def demo():
    f1 = open('sample1.txt', 'w')
    f1.write("Hello NLP! \n")
    f1.write("This is file Handelling.")
    f1.close()
demo()

# %%
def demo2():
    f2 = open('sample2.txt', 'w')
    for x in range(1, 10):
        f2.write(str(x))
        f2.write('\n')
    f2.close()
demo2()

# %% [markdown]
# # Reading from a file

# %%
f3 = open('sample1.txt', 'r')
text = f3.read()
text
# Out:
# 'Hello NLP! \nThis is file Handelling.'

# %%
f3 = open('sample1.txt', 'r')
for text in f3:
    print(text)
# Out:
# Hello NLP!
#
# This is file Handelling.

# %% [markdown]
# # Reading Numbers From a File

# %%
f = open('sample2.txt', 'r')
text = f.read()
print(text)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
print("NLP")
# Out:
# NLP

# %% [markdown]
# # Writing to a file

# %%
# open('sample1.txt', 'w')
def demo():
    f1 = open('sample1.txt', 'w')
    f1.write("Hello NLP! \n")
    f1.write("This is file Handelling.")
    f1.close()
demo()

# %%
def demo2():
    f2 = open('sample2.txt', 'w')
    for x in range(1, 10):
        f2.write(str(x))
        f2.write('\n')
    f2.close()
demo2()

# %% [markdown]
# # Reading from a file

# %%
f3 = open('sample1.txt', 'r')
text = f3.read()
text
# Out:
# 'Hello NLP! \nThis is file Handelling.'

# %%
f3 = open('sample1.txt', 'r')
for text in f3:
    print(text)
# Out:
# Hello NLP!
#
# This is file Handelling.

# %% [markdown]
# # Reading Numbers From a File

# %%
f = open('sample2.txt', 'r')
text = f.read()
print(text)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
f4 = open('sample2.txt', 'r')
total = 0
for i in range(10):
    line = f4.readline()
    if not line:   # EOF
        break
    total += int(line.strip())
print(total)
# Out:
# 45
