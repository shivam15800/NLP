# %%
person="Jose"
print("my name is {}".format(person))
# Out:
# my name is Jose

# %%
print(f"my name is {person}")
# Out:
# my name is Jose

# %%
print("my name is {person}")
# Out:
# my name is {person}

# %%
print(F"my name is {person}")
# Out:
# my name is Jose

# %%
d={'a':123,'b':456}
print(f"my number is {d['a']}")
# Out:
# my number is 123

# %%
mylist= [0,1,2]
print(f"my number is {mylist[0]}")
# Out:
# my number is 0

# %%
library=[('Author','Topic','Pages'), ('Twain','Rafting',601),('Feynman','Physics',95),('Hamilton','Mythology',144)]
for book in library:
    print(f"{book[0]}")
# Out:
# Author
# Twain
# Feynman
# Hamilton

# %%
for author,topic,pages in library:
    print(f"Author is {author}")
# Out:
# Author is Author
# Author is Twain
# Author is Feynman
# Author is Hamilton

# %%
for author,topic,pages in library:
    print(f" {author} {topic} {pages}")
# Out:
#  Author Topic Pages
#  Twain Rafting 601
#  Feynman Physics 95
#  Hamilton Mythology 144

# %%
library=[('Author','Topic','Pages'), ('Twain','Rafting in Water',601),('Feynman','Physics',95),('Hamilton','Mythology',144)]
for author,topic,pages in library:
    print(f" {author} {topic} {pages}")
# Out:
#  Author Topic Pages
#  Twain Rafting in Water 601
#  Feynman Physics 95
#  Hamilton Mythology 144

# %%
for author,topic,pages in library:
    print(f" {author:{10}} {topic:{30}} {pages:{10}}")
# Out:
#  Author     Topic                          Pages
#  Twain      Rafting in Water                      601
#  Feynman    Physics                                95
#  Hamilton   Mythology                             144

# %%
for author,topic,pages in library:
    print(f" {author:{10}} {topic:{30}} {pages:>{10}}")
# Out:
#  Author     Topic                               Pages
#  Twain      Rafting in Water                      601
#  Feynman    Physics                                95
#  Hamilton   Mythology                             144

# %%
for author,topic,pages in library:
    print(f" {author:{10}} {topic:{30}} {pages:.>{10}}")
# Out:
#  Author     Topic                          .....Pages
#  Twain      Rafting in Water               .......601
#  Feynman    Physics                        ........95
#  Hamilton   Mythology                      .......144

# %%
from datetime import datetime

# %%
today=datetime(year=2019,month=2,day=28)
print(f"{today}")
# Out:
# 2019-02-28 00:00:00

# %%
print(f"{today:%B}")
# Out:
# February

# %%
print(f"{today:%B %d}")
# Out:
# February 28

# %%
print(f"{today:%B %d, %Y}")
# Out:
# February 28, 2019

# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Writing test.txt

# %%
# %%writefile test2.txt
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Overwriting test2.txt

# %%
myfile=open('whoops.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-d069fcb76d07> in <module>
# ----> 1 myfile=open('whoops.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops.txt'

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\Anaconda Projects\\AnacondaProjects'

# %%
myfile=open('test2.txt')
myfile
# Out:
# <_io.TextIOWrapper name='test2.txt' mode='r' encoding='cp1252'>

# %%
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.close()

# %%
myfile=open('test.txt')
myfile.readlines()
# Out:
# ['Hello, this is a quick test file.\n',
#  'This is the second line of the file.\n']

# %%
mylines=myfile.readlines()
print(mylines)
# Out:
# []

# %%
myfile.seek(0)
mylines=myfile.readlines()
for line in mylines:
    print(line[0])
# Out:
# H
# T

# %%
for line in mylines:
    print(line.split()[0])
# Out:
# Hello,
# This

# %%
myfile=open('test.txt','w+')
myfile.read()
# Out:
# ''

# %%
myfile.write('My brand new text')
myfile.seek(0)
myfile.read()
# Out:
# 'My brand new text'

# %%
myfile.close()

# %%
myfile=open('test2.txt','a+')

# %%
myfile.write('My first line in a+ opening')
# Out:
# 27

# %%
myfile.close()

# %%
myfile=open('test2.txt')
myfile.read()
# Out:
# 'My first line in a+ opening'

# %%
myfile.close()

# %%
myfile=open('test2.txt',mode='a+')
myfile.write('This is an added line')
myfile.seek(0)
myfile.read()
# Out:
# 'My first line in a+ openingThis is an added line\n This is an added line\n This is an added lineThis is an added line'

# %%
myfile.write('\n This is a real new line')
myfile.seek(0)
myfile.read()
# Out:
# 'My first line in a+ openingThis is an added line\n This is an added line\n This is an added lineThis is an added line\n This is an added line\n This is a real new line/n This is a real new line\n This is a real new line'

# %%
myfile.seek(0)
print(myfile.read())
# Out:
# My first line in a+ openingThis is an added line
#  This is an added line
#  This is an added lineThis is an added line
#  This is an added line
#  This is a real new line/n This is a real new line
#  This is a real new line

# %%
myfile.close()

# %%
with open('test2.txt','r') as mynewfile:           #This will automatically close the file
    myvariable= mynewfile.readlines()
myvariable
# Out:
# ['My first line in a+ openingThis is an added line\n', ' This is an added line\n', ' This is an added lineThis is an added line\n', ' This is an added line\n', ' This is a real new line/n This is a real new line\n', ' This is a real new line']

# %%
print(myvariable)
# Out:
# ['My first line in a+ openingThis is an added line\n', ' This is an added line\n', ' This is an added lineThis is an added line\n', ' This is an added line\n', ' This is a real new line/n This is a real new line\n', ' This is a real new line']
